# %%
#implementation of Gradient Descent in Linear Regression
import matplotlib.pyplot as plt
import pandas as pd
#data = [[1,2,3,4,12,21,7,45,19,91],[5,6,7,8,91,5,77,70,17,23]]
data = pd.read_excel("IGT.xls")
b0 = 0
b1 = 0
dt0 = []
dt1 = []
print(data.iloc[6,0])
for i in range(1,10):
    for j in range(0,10):
        t1 = -data.iloc[j,1]*(data.iloc[j,28]-(b0*data.iloc[j,1] + b1))
        t2 = -(data.iloc[j,28] -(b0 * data.iloc[j,1] + b1))
    b0 = b0 - 0.005 * (2 / 60.0) * t1
    b1 = b1 - 0.005 * (2 / 60.0) * t2
    dt0.append(b0)
    dt1.append(b1)
    #print("B0:",b0,"B1:",b1)
    #plotting GD
print("printing Beta0")
print(dt0)
print("printing Beta1")
print(dt1)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(dt0,dt1,"-" ) 
#ax.plot(dt0,dt0)
ax.plot(data)
plt.show()
# Out:
# 198000000000
# printing Beta0
# [2.3088333333333333, -1502.4509729444444, 979210.20675713639, -638190784.24646485, 415934674457.36121, -271081403375729.75, 1.7667468419656589e+17, -1.1514601756983124e+20, 7.5045303872967674e+22]
# printing Beta1
# [0.0011666666666666665, -0.7591970555555555, 494.80050872012959, -322481.44732009346, 210174165.97138008, -136978980988.24144, 89274726728936.781, -58183940156559504.0, 3.79208205522828e+19]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-1e1afbf85487> in <module>()
#      25 fig = plt.figure()
#      26 ax = fig.add_subplot(1,1,1)
# ---> 27 ax.scatter(dt0,dt1,"-" )
#      28 #ax.plot(dt0,dt0)
#      29 ax.plot(data)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1816                     warnings.warn(msg % (label_namer, func.__name__),
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 76D7-711B
#
#  Directory of C:\Users\Admin\CharuDataScience
#
# 31-12-2016  10:09 AM    <DIR>          .
# 31-12-2016  10:09 AM    <DIR>          ..
# 31-12-2016  10:09 AM    <DIR>          .ipynb_checkpoints
# 31-12-2016  08:21 AM        10,258,040 india_globalterrorismdb_0616dist.csv
# 27-12-2016  05:29 PM             9,521 K_meansHW_TomMitchell_data1.csv
# 30-12-2016  12:08 AM    <DIR>          LogReg
# 29-12-2016  11:57 PM    <DIR>          MovieDS
# 28-12-2016  11:11 AM           177,177 movies.csv
# 26-03-2003  03:18 PM           171,308 movies.dat
# 31-12-2016  10:07 AM    <DIR>          Project
# 30-12-2016  12:11 AM            17,139 PROJECT LIST.docx
# 28-02-2003  03:53 PM        24,594,131 ratings.dat
# 29-01-2016  02:39 PM             5,577 README
# 31-12-2016  10:09 AM             9,898 TimeAttackGD.ipynb
# 27-12-2016  02:35 PM            10,085 Untitled.ipynb
# ...

# %%
#implementation of Gradient Descent in Linear Regression
import matplotlib.pyplot as plt
import pandas as pd
#data = [[1,2,3,4,12,21,7,45,19,91],[5,6,7,8,91,5,77,70,17,23]]
data = pd.read_excel("IGT.xls")
b0 = 0
b1 = 0
dt0 = []
dt1 = []
print(data.iloc[6,0])
for i in range(1,10):
    for j in range(0,10):
        t1 = -data.iloc[j,1]*(data.iloc[j,28]-(b0*data.iloc[j,1] + b1))
        t2 = -(data.iloc[j,28] -(b0 * data.iloc[j,1] + b1))
    b0 = b0 - 0.005 * (2 / 60.0) * t1
    b1 = b1 - 0.005 * (2 / 60.0) * t2
    dt0.append(b0)
    dt1.append(b1)
    #print("B0:",b0,"B1:",b1)
    #plotting GD
print("printing Beta0")
print(dt0)
print("printing Beta1")
print(dt1)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(dt0,dt1,"-" ) 
plt.title('Attack Vs Year')
plt.xlabel('iyear')
plt.ylabel('attacktype1')
#ax.plot(dt0,dt0)
#ax.plot(data)
plt.show()
# Out:
# 198000000000
# printing Beta0
# [2.3088333333333333, -1502.4509729444444, 979210.20675713639, -638190784.24646485, 415934674457.36121, -271081403375729.75, 1.7667468419656589e+17, -1.1514601756983124e+20, 7.5045303872967674e+22]
# printing Beta1
# [0.0011666666666666665, -0.7591970555555555, 494.80050872012959, -322481.44732009346, 210174165.97138008, -136978980988.24144, 89274726728936.781, -58183940156559504.0, 3.79208205522828e+19]

# %%
#implementation of Gradient Descent in Linear Regression
import matplotlib.pyplot as plt
import pandas as pd
#data = [[1,2,3,4,12,21,7,45,19,91],[5,6,7,8,91,5,77,70,17,23]]
data = pd.read_excel("IGT.xls")
b0 = 0
b1 = 0
dt0 = []
dt1 = []
print(data.iloc[6,0])
for i in range(1,10):
    for j in range(0,10):
        t1 = -data.iloc[j,1]*(data.iloc[j,28]-(b0*data.iloc[j,1] + b1))
        t2 = -(data.iloc[j,28] -(b0 * data.iloc[j,1] + b1))
    b0 = b0 - 0.005 * (2 / 60.0) * t1
    b1 = b1 - 0.005 * (2 / 60.0) * t2
    dt0.append(b0)
    dt1.append(b1)
    #print("B0:",b0,"B1:",b1)
    #plotting GD
print("printing Beta0")
print(dt0)
print("printing Beta1")
print(dt1)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(dt0,dt1,"-" ) 
plt.title('Attack Verses Year')
plt.xlabel('Year')
plt.ylabel('Attack Type')
#ax.plot(dt0,dt0)
#ax.plot(data)
plt.show()
# Out:
# 198000000000
# printing Beta0
# [2.3088333333333333, -1502.4509729444444, 979210.20675713639, -638190784.24646485, 415934674457.36121, -271081403375729.75, 1.7667468419656589e+17, -1.1514601756983124e+20, 7.5045303872967674e+22]
# printing Beta1
# [0.0011666666666666665, -0.7591970555555555, 494.80050872012959, -322481.44732009346, 210174165.97138008, -136978980988.24144, 89274726728936.781, -58183940156559504.0, 3.79208205522828e+19]

# %%
#implementation of Gradient Descent in Linear Regression
import matplotlib.pyplot as plt
import pandas as pd
#data = [[1,2,3,4,12,21,7,45,19,91],[5,6,7,8,91,5,77,70,17,23]]
data = pd.read_excel("IGT.xls")
b0 = 0
b1 = 0
dt0 = []
dt1 = []
print(data.iloc[6,0])
for i in range(1,100):
    for j in range(0,50):
        t1 = -data.iloc[j,1]*(data.iloc[j,28]-(b0*data.iloc[j,1] + b1))
        t2 = -(data.iloc[j,28] -(b0 * data.iloc[j,1] + b1))
    b0 = b0 - 0.005 * (2 / 60.0) * t1
    b1 = b1 - 0.005 * (2 / 60.0) * t2
    dt0.append(b0)
    dt1.append(b1)
    #print("B0:",b0,"B1:",b1)
    #plotting GD
print("printing Beta0")
print(dt0)
print("printing Beta1")
print(dt1)
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(dt0,dt1,"-" ) 
plt.title('Attack Verses Year')
plt.xlabel('Year')
plt.ylabel('Attack Type')
#ax.plot(dt0,dt0)
#ax.plot(data)
plt.show()
# Out:
# 198000000000
# printing Beta0
# ...
